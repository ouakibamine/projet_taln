# %%
import warnings
warnings.filterwarnings("ignore")
# !python cnn_gru_svm_main.py \
  --operation train \
  --train_dataset ./prepared_data/X_train.npy \
  --train_labels ./prepared_data/y_train.npy \
  --validation_dataset ./prepared_data/X_val.npy \
  --validation_labels ./prepared_data/y_val.npy \
  --checkpoint_path ./checkpoints \
  --log_path ./logs \
  --model_name emotion_cnn_gru_svm \
  --result_path ./results_cnn
# Out:
# 2025-04-30 22:52:31.611286: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746053551.722461   17752 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746053551.752305   17752 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746053551.998417   17752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746053551.998748   17752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746053551.998754   17752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746053551.998758   17752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-30 22:52:32.035755: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
#
# <log> Building Graph...WARNING:tensorflow:From /teamspace/studios/this_studio/models/gru_svm/cnn_gru_svm.py:92: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tensorflow/python/ops/rnn.py:441: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:584: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:594: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# </log>
# Training samples:   16640
# Validation samples: 4096
# Début de l'entraînement...
# I0000 00:00:1746053558.781013   17752 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746053558.815286   17752 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# I0000 00:00:1746053560.678786   18066 cuda_dnn.cc:529] Loaded cuDNN version 90701
# step [0] | train loss=5.2121 train acc=0.1367 | val loss=5.2184 val acc=0.1309
# step [100] | train loss=1.6796 train acc=0.1797 | val loss=1.7542 val acc=0.2043
# step [200] | train loss=1.6596 train acc=0.2383 | val loss=1.6630 val acc=0.2207
# step [300] | train loss=1.5262 train acc=0.3789 | val loss=1.5876 val acc=0.3633
# step [400] | train loss=1.4320 train acc=0.3359 | val loss=1.5105 val acc=0.2905
# step [500] | train loss=1.2781 train acc=0.3750 | val loss=1.4092 val acc=0.3159
# WARNING:tensorflow:From /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tensorflow/python/training/saver.py:1068: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# step [600] | train loss=1.0551 train acc=0.5117 | val loss=1.3283 val acc=0.4575
# step [700] | train loss=0.9962 train acc=0.6133 | val loss=1.2759 val acc=0.5034
# step [800] | train loss=0.7747 train acc=0.6406 | val loss=1.2382 val acc=0.5044
# step [900] | train loss=0.6591 train acc=0.5859 | val loss=1.2070 val acc=0.4587
# step [1000] | train loss=0.6365 train acc=0.5859 | val loss=1.1960 val acc=0.4443
# step [1100] | train loss=0.5374 train acc=0.6211 | val loss=1.1584 val acc=0.4841
# step [1200] | train loss=0.4552 train acc=0.5430 | val loss=1.1802 val acc=0.4500
# step [1300] | train loss=0.4057 train acc=0.6602 | val loss=1.1185 val acc=0.4709
# step [1400] | train loss=0.3214 train acc=0.6250 | val loss=1.1114 val acc=0.5020
# step [1500] | train loss=0.3190 train acc=0.5938 | val loss=1.1540 val acc=0.4399
# step [1600] | train loss=0.3228 train acc=0.6875 | val loss=1.1784 val acc=0.5349
# step [1700] | train loss=0.2559 train acc=0.6484 | val loss=1.1216 val acc=0.4822
# step [1800] | train loss=0.2383 train acc=0.6445 | val loss=1.0902 val acc=0.4751
# step [1900] | train loss=0.2211 train acc=0.6289 | val loss=1.0573 val acc=0.5046
# step [2000] | train loss=0.2380 train acc=0.6133 | val loss=1.0699 val acc=0.4414
# step [2100] | train loss=0.1796 train acc=0.6016 | val loss=1.0728 val acc=0.4536
# step [2200] | train loss=0.1583 train acc=0.5859 | val loss=1.0310 val acc=0.4543
# step [2300] | train loss=0.1800 train acc=0.6055 | val loss=1.0945 val acc=0.4343
# step [2400] | train loss=0.1836 train acc=0.6016 | val loss=1.0279 val acc=0.4783
# step [2500] | train loss=0.1776 train acc=0.5352 | val loss=1.1181 val acc=0.4380
# step [2600] | train loss=0.1585 train acc=0.6836 | val loss=1.0222 val acc=0.5012
# step [2700] | train loss=0.1282 train acc=0.5547 | val loss=1.1134 val acc=0.4380
# step [2800] | train loss=0.1520 train acc=0.6055 | val loss=0.9989 val acc=0.4666
# step [2900] | train loss=0.1385 train acc=0.5742 | val loss=1.0409 val acc=0.4441
# step [3000] | train loss=0.1157 train acc=0.6289 | val loss=0.9941 val acc=0.4629
# step [3100] | train loss=0.1133 train acc=0.6094 | val loss=1.0401 val acc=0.4692
# step [3200] | train loss=0.1182 train acc=0.5625 | val loss=1.0239 val acc=0.4495
# step [3300] | train loss=0.1196 train acc=0.6289 | val loss=0.9863 val acc=0.4741
# step [3400] | train loss=0.0810 train acc=0.5938 | val loss=0.9723 val acc=0.4561
# step [3500] | train loss=0.0807 train acc=0.6523 | val loss=0.9885 val acc=0.5090
# step [3600] | train loss=0.0793 train acc=0.6250 | val loss=0.9445 val acc=0.4780
# step [3700] | train loss=0.0911 train acc=0.6602 | val loss=0.9647 val acc=0.5105
# step [3800] | train loss=0.0865 train acc=0.6289 | val loss=0.9403 val acc=0.5208
# step [3900] | train loss=0.0745 train acc=0.6836 | val loss=0.9578 val acc=0.4866
# step [4000] | train loss=0.0623 train acc=0.6328 | val loss=0.9623 val acc=0.5295
# step [4100] | train loss=0.0741 train acc=0.6289 | val loss=0.9460 val acc=0.4719
# step [4200] | train loss=0.0633 train acc=0.6328 | val loss=0.9757 val acc=0.4888
# step [4300] | train loss=0.0565 train acc=0.7383 | val loss=0.9180 val acc=0.5337
# step [4400] | train loss=0.0631 train acc=0.6172 | val loss=0.9847 val acc=0.4592
# step [4500] | train loss=0.0623 train acc=0.7539 | val loss=0.9773 val acc=0.5847
# step [4600] | train loss=0.0562 train acc=0.6445 | val loss=0.9582 val acc=0.4861
# step [4700] | train loss=0.0494 train acc=0.7461 | val loss=0.9410 val acc=0.5737
# step [4800] | train loss=0.0475 train acc=0.7109 | val loss=0.9305 val acc=0.5605
# step [4900] | train loss=0.0481 train acc=0.6328 | val loss=0.9305 val acc=0.4858
# step [5000] | train loss=0.0539 train acc=0.7266 | val loss=0.9635 val acc=0.5898
# step [5100] | train loss=0.0528 train acc=0.5430 | val loss=1.0094 val acc=0.4519
# step [5200] | train loss=0.0461 train acc=0.7344 | val loss=0.9290 val acc=0.5391
# step [5300] | train loss=0.0402 train acc=0.5586 | val loss=0.9404 val acc=0.4580
# step [5400] | train loss=0.0393 train acc=0.6953 | val loss=0.8834 val acc=0.5229
# step [5500] | train loss=0.0338 train acc=0.6289 | val loss=0.8639 val acc=0.5134
# step [5600] | train loss=0.0304 train acc=0.6523 | val loss=0.8625 val acc=0.4934
# step [5700] | train loss=0.0304 train acc=0.6953 | val loss=0.8660 val acc=0.5435
# step [5800] | train loss=0.0295 train acc=0.6328 | val loss=0.8647 val acc=0.5083
# step [5900] | train loss=0.0295 train acc=0.6758 | val loss=0.8677 val acc=0.4976
# step [6000] | train loss=0.0266 train acc=0.6445 | val loss=0.8595 val acc=0.5225
# step [6100] | train loss=0.0300 train acc=0.5938 | val loss=0.9015 val acc=0.4673
# step [6200] | train loss=0.0270 train acc=0.7773 | val loss=0.8746 val acc=0.5923
# step [6300] | train loss=0.0320 train acc=0.6289 | val loss=0.9075 val acc=0.5220
# step [6400] | train loss=0.0303 train acc=0.6445 | val loss=0.8893 val acc=0.5415
# step [6500] | train loss=0.0334 train acc=0.7188 | val loss=0.9521 val acc=0.5208
# step [6600] | train loss=0.0258 train acc=0.5742 | val loss=0.8624 val acc=0.4746
# step [6700] | train loss=0.0258 train acc=0.7812 | val loss=0.9108 val acc=0.6023
# step [6800] | train loss=0.0235 train acc=0.5859 | val loss=0.8872 val acc=0.4707
# step [6900] | train loss=0.0225 train acc=0.6133 | val loss=0.9025 val acc=0.4705
# step [7000] | train loss=0.0239 train acc=0.6016 | val loss=0.8987 val acc=0.4700
# step [7100] | train loss=0.0266 train acc=0.5859 | val loss=0.9543 val acc=0.4600
# step [7200] | train loss=0.0235 train acc=0.6641 | val loss=0.8703 val acc=0.5093
# step [7300] | train loss=0.0240 train acc=0.5938 | val loss=0.8911 val acc=0.4651
# step [7400] | train loss=0.0203 train acc=0.6211 | val loss=0.8547 val acc=0.4851
# step [7500] | train loss=0.0180 train acc=0.6133 | val loss=0.8311 val acc=0.4841
# step [7600] | train loss=0.0217 train acc=0.5898 | val loss=0.9088 val acc=0.4727
# step [7700] | train loss=0.0177 train acc=0.5586 | val loss=0.8209 val acc=0.4866
# step [7800] | train loss=0.0227 train acc=0.7969 | val loss=0.8938 val acc=0.5798
# step [7900] | train loss=0.0169 train acc=0.6328 | val loss=0.8193 val acc=0.5112
# step [8000] | train loss=0.0221 train acc=0.6328 | val loss=0.8755 val acc=0.5232
# step [8100] | train loss=0.0164 train acc=0.6328 | val loss=0.8357 val acc=0.4905
# step [8200] | train loss=0.0199 train acc=0.7344 | val loss=0.9762 val acc=0.5596
# step [8300] | train loss=0.0153 train acc=0.6328 | val loss=0.8387 val acc=0.4963
# step [8400] | train loss=0.0176 train acc=0.6914 | val loss=0.9028 val acc=0.5225
# step [8500] | train loss=0.0145 train acc=0.7109 | val loss=0.8422 val acc=0.5527
# step [8600] | train loss=0.0170 train acc=0.6055 | val loss=0.9240 val acc=0.4880
# step [8700] | train loss=0.0144 train acc=0.6211 | val loss=0.8632 val acc=0.5032
# step [8800] | train loss=0.0153 train acc=0.8086 | val loss=0.8582 val acc=0.6125
# step [8900] | train loss=0.0132 train acc=0.6328 | val loss=0.8319 val acc=0.5144
# step [9000] | train loss=0.0162 train acc=0.5469 | val loss=0.9211 val acc=0.4697
# step [9100] | train loss=0.0154 train acc=0.6875 | val loss=0.8884 val acc=0.5049
# step [9200] | train loss=0.0159 train acc=0.6445 | val loss=0.9416 val acc=0.5317
# step [9300] | train loss=0.0128 train acc=0.6484 | val loss=0.8264 val acc=0.5291
# step [9400] | train loss=0.0146 train acc=0.5938 | val loss=0.9229 val acc=0.4656
# step [9500] | train loss=0.0134 train acc=0.7188 | val loss=0.8791 val acc=0.5591
# step [9600] | train loss=0.0141 train acc=0.6758 | val loss=0.9430 val acc=0.5347
# step [9700] | train loss=0.0110 train acc=0.7305 | val loss=0.8010 val acc=0.5645
# Entraînement terminé.
# step [0] val loss=0.8072 val acc=0.8281
# Validation: avg loss=0.9028, avg acc=0.8147
# Validation terminée.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix
class_names = ["anger","disgust","fear","joy","sadness","surprise"]
result_path ="results_cnn/"
file_path = os.path.join(result_path, "preds_acts.txt")

preds = []
acts = []

with open(file_path, "r") as f:
    next(f)  # Sauter l'en-tête "Prediction\tActual"
    for line in f:
        pred_str, act_str = line.strip().split('\t')
        
        # Nettoyage : enlever [ ] puis splitter sur les espaces
        pred_values = np.array(pred_str.strip('[]').split(), dtype=float)
        act_values = np.array(act_str.strip('[]').split(), dtype=float)
        
        preds.append(np.argmax(pred_values))
        acts.append(np.argmax(act_values))

preds = np.array(preds)
acts = np.array(acts)

# Calcul de la matrice de confusion
conf = confusion_matrix(acts, preds)

# Affichage
plt.figure(figsize=(8, 6))
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Annoter les cases avec les valeurs
thresh = conf.max() / 2.0
for i in range(conf.shape[0]):
    for j in range(conf.shape[1]):
        plt.text(j, i, format(conf[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
# --- Precision, Recall, F1-Score ---
report = classification_report(acts, preds, target_names=class_names, digits=4)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        anger     0.8069    0.9425    0.8694      2070
#      disgust     0.8043    0.7121    0.7554       837
#         fear     0.7768    0.7424    0.7592       361
#          joy     0.8828    0.6719    0.7630       381
#      sadness     0.8714    0.6162    0.7219       396
#     surprise     1.0000    0.4314    0.6027        51
#
#     accuracy                         0.8147      4096
#    macro avg     0.8570    0.6861    0.7453      4096
# weighted avg     0.8194    0.8147    0.8089      4096
